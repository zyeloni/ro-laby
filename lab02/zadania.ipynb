# %%
#zad 2
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
# %matplotlib inline
from skimage import data
camera = data.camera()
astro = data.astronaut()
invert1 = (255-camera)
invert2 = (255-astro)
plt.subplot(121)
plt.imshow(invert1)
plt.axis('off')
plt.subplot(122)
plt.imshow(invert2)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
#zad4
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage import data
astro = data.astronaut()
cv2.circle(astro,center=(230,100),radius=100,color=(0,255,0),thickness=10)
plt.imshow(astro)

# %%
#zad 3
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
import scipy.misc
# %matplotlib inline
from skimage import data

camera = data.camera()
face = scipy.misc.face(gray=True)
face = np.flip(face)
face = cv2.resize(face, dsize=(512, 512), interpolation=cv2.INTER_CUBIC)

res = 0.5 * camera + 0.5 * face
plt.imshow(res)

# %%
#zad 5
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
import scipy.misc
# %matplotlib inline
from skimage import data
camera = data.camera()
nrows, ncols = camera.shape
row, col = np.ogrid[:nrows, :ncols]
cnt_row, cnt_col = nrows / 2, ncols / 2
inter_disk_mask = ((row - cnt_row)**2 + (col - cnt_col)**2 < (nrows / 2)**2)
camera[inter_disk_mask] = (255-camera[inter_disk_mask])
plt.imshow(camera, cmap='gray')
